# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('cities_r2.csv')

# %%
df.shape
# Out:
# (493, 22)

# %%
df.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# 25%         6.041100e+04          1.363900e+04          7221.000000
# 50%         8.776800e+04          1.944000e+04         10342.000000
# 75%         1.700260e+05          3.794500e+04         19982.000000
# max         5.741632e+06          1.209275e+06        647938.000000
#
#        0-6_population_female  literates_total  literates_male  \
# count             493.000000     4.930000e+02    4.930000e+02
# mean            22243.320487     3.461527e+05    1.894384e+05
# std             49523.241379     8.220952e+05    4.534753e+05
# min              3107.000000     5.699800e+04    3.475100e+04
# 25%              6457.000000     9.768700e+04    5.357800e+04
# 50%              9172.000000     1.413290e+05    7.590600e+04
# 75%             17954.000000     2.679000e+05    1.455480e+05
# max            561337.000000     1.023759e+07    5.727774e+06
#
#        literates_female    sex_ratio  child_sex_ratio  \
# count      4.930000e+02   493.000000       493.000000
# mean       1.567143e+05   930.294118       902.332657
# std        3.690677e+05    55.849106        49.794689
# min        2.224700e+04   700.000000       762.000000
# 25%        4.391400e+04   890.000000       868.000000
# 50%        6.383600e+04   922.000000       903.000000
# 75%        1.235030e+05   971.000000       942.000000
# max        4.509812e+06  1093.000000      1185.000000
#
#        effective_literacy_rate_total  effective_literacy_rate_male  \
# count                     493.000000                    493.000000
# mean                       85.131460                     89.920162
# std                         6.186345                      5.377492
# min                        49.510000                     52.270000
# 25%                        81.750000                     87.280000
# 50%                        85.970000                     91.180000
# 75%                        89.330000                     93.400000
# max                        98.800000                     99.300000
#
#        effective_literacy_rate_female  total_graduates  male_graduates  \
# count                      493.000000     4.930000e+02    4.930000e+02
# mean                        79.967181     6.620236e+04    3.771556e+04
# std                          7.577825     1.778187e+05    9.849574e+04
# min                         46.450000     2.532000e+03    1.703000e+03
# 25%                         75.800000     1.527700e+04    9.289000e+03
# 50%                         80.920000     2.395900e+04    1.404900e+04
# 75%                         85.400000     5.036700e+04    2.787200e+04
# max                         98.310000     2.221137e+06    1.210040e+06
#
#        female_graduates
# count      4.930000e+02
# mean       2.848680e+04
# std        7.951556e+04
# min        8.290000e+02
# 25%        6.114000e+03
# 50%        9.558000e+03
# 75%        2.086600e+04
# max        1.011097e+06

# %% [markdown]
# **Describing the datatypes**

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %% [markdown]
# **Histogram plot of Sex-Ratio**

# %%
figure = plt.figure(figsize=(15,8))
plt.hist(df['sex_ratio'],color = 'olive',bins = 30)
plt.xlabel('sex_ratio')
plt.ylabel('count of cities')
plt.title('Histogram of Sex-ratio')
# Out:
# Text(0.5, 1.0, 'Histogram of Sex-ratio')

# %% [markdown]
# **Histogram plot of Child Sex-Ratio**

# %%
figure = plt.figure(figsize=(15,8))
plt.hist(df['child_sex_ratio'],color = 'skyblue',bins = 30)
plt.xlabel('sex_ratio')
plt.ylabel('count of cities')
plt.title('Histogram of Child-Sex-ratio')
# Out:
# Text(0.5, 1.0, 'Histogram of Child-Sex-ratio')

# %% [markdown]
# **The distribution of Child-Sex Ratio**

# %%
sns.distplot(df['child_sex_ratio'],rug = True)
# Out:
# <AxesSubplot:xlabel='child_sex_ratio', ylabel='Density'>

# %% [markdown]
# **Kozhikode is the city with highest Sex-Ratio**

# %%
df.sort_values('sex_ratio',ascending = False)[:1]
# Out:
#     name_of_city  state_code state_name  dist_code  population_total  \
# 278   Kozhikode           32     KERALA          4            432097
#
#      population_male  population_female  0-6_population_total  \
# 278           206494             225603                 41574
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 278                21208                  20366  ...            196582
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 278       1093              960                           96.8
#
#      effective_literacy_rate_male  effective_literacy_rate_female  \
# 278                         97.93                           95.78
#
#                 location  total_graduates male_graduates  female_graduates
# 278  11.2587531,75.78041            61225          27701             33524
#
# [1 rows x 22 columns]

# %% [markdown]
# **Bhiwandi is the city with lowest Sex-Ratio**

# %%
df.sort_values('sex_ratio')[:1]
# Out:
#    name_of_city  state_code   state_name  dist_code  population_total  \
# 89    Bhiwandi           27  MAHARASHTRA         21            711329
#
#     population_male  population_female  0-6_population_total  \
# 89           418478             292851                 88613
#
#     0-6_population_male  0-6_population_female  ...  literates_female  \
# 89                45820                  42793  ...            192816
#
#     sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 89        700              934                          81.53
#
#     effective_literacy_rate_male  effective_literacy_rate_female  \
# 89                          84.5                           77.11
#
#                  location  total_graduates male_graduates  female_graduates
# 89  19.2812547,73.0482912            24688          14404             10284
#
# [1 rows x 22 columns]

# %% [markdown]
# **Mean of Sex-Ratio grouped by states and Sorted by Sex-Ratio in ascending order**

# %%
df['sex_ratio'].groupby(df['state_name']).mean().sort_values()
#lowest 5 states
# Out:
# state_name
# HIMACHAL PRADESH              818.000000
# CHANDIGARH                    829.000000
# NCT OF DELHI                  861.533333
# HARYANA                       875.800000
# PUNJAB                        887.062500
# BIHAR                         887.884615
# ANDAMAN & NICOBAR ISLANDS     889.000000
# UTTAR PRADESH                 891.285714
# UTTARAKHAND                   892.333333
# JHARKHAND                     903.000000
# NAGALAND                      904.000000
# JAMMU & KASHMIR               907.666667
# RAJASTHAN                     908.517241
# GUJARAT                       913.172414
# MADHYA PRADESH                914.812500
# MAHARASHTRA                   920.511628
# ORISSA                        930.300000
# WEST BENGAL                   943.262295
# CHHATTISGARH                  950.222222
# ASSAM                         950.750000
# KARNATAKA                     987.115385
# ANDHRA PRADESH                999.404762
# TAMIL NADU                   1001.031250
# TRIPURA                      1002.000000
# MIZORAM                      1029.000000
# PUDUCHERRY                   1035.000000
# MEGHALAYA                    1042.000000
# MANIPUR                      1055.000000
# KERALA                       1066.714286
# Name: sex_ratio, dtype: float64

# %% [markdown]
# **Table showing Top 5 States that have lowest Sex-Ratio.**

# %%
data_sex = pd.DataFrame(df['sex_ratio'].groupby(df['state_name']).mean().sort_values()[:5])
data_sex
# Out:
#                    sex_ratio
# state_name
# HIMACHAL PRADESH  818.000000
# CHANDIGARH        829.000000
# NCT OF DELHI      861.533333
# HARYANA           875.800000
# PUNJAB            887.062500

# %% [markdown]
# **Himachal Pradesh has lowest Sex-Ratio**

# %% [markdown]
# **Making a DataFrame of Cities which has lowest Sex-Ratio(5cities)**

# %%
data_sex_worst_city = pd.DataFrame(df['sex_ratio'].groupby(df['name_of_city']).mean().sort_values()[:5])
data_sex_worst_city['city_name'] = data_sex_worst_city.index.values

# %% [markdown]
# **Making a DataFrame of Cities which has highest Sex-Ratio(5cities)**

# %%
data_sex_best_city = pd.DataFrame(df['sex_ratio'].groupby(df['name_of_city']).mean().sort_values(ascending = False)[:5])
data_sex_best_city['city_name'] = data_sex_best_city.index.values
frames = [data_sex_worst_city,data_sex_best_city]

# %%
data_sex_worst_city = pd.DataFrame(df['sex_ratio'].groupby(df['name_of_city']).mean().sort_values()[:5])

# %%
data_sex_best_city = pd.DataFrame(df['sex_ratio'].groupby(df['name_of_city']).mean().sort_values(ascending = False)[:5])
frames = [data_sex_worst_city,data_sex_best_city]

# %% [markdown]
# **Concatenate top 5 and bottom 5 cities on the basis of the Sex-Ratio**

# %%
###Analysis of top 5 and bottom 5 cities on the basis of number of male graduates::
total = pd.concat(frames)
total
# Out:
#                      sex_ratio
# name_of_city
# Bhiwandi                 700.0
# Delhi Cantonment         719.0
# Bhiwadi                  755.0
# Surat                    758.0
# Pithampur                787.0
# Kozhikode               1093.0
# Kollam                  1077.0
# Alappuzha               1076.0
# Thrissur                1076.0
# Thiruvananthapuram      1064.0

# %% [markdown]
# **Best 5 cities with Highest number of Female Graduates**

# %%
data_female_graduates_best_city = pd.DataFrame(df['female_graduates'].groupby(df['name_of_city']).mean().sort_values(ascending = False)[:5])
data_female_graduates_best_city['city_name'] = data_female_graduates_best_city.index.values
data_female_graduates_best_city
# Out:
#                     female_graduates           city_name
# name_of_city
# Delhi                        1011097              Delhi
# Greater Mumbai                837407     Greater Mumbai
# Bengaluru                     682800           Bengaluru
# Greater Hyderabad             478747  Greater Hyderabad
# Chennai                       392267            Chennai

# %% [markdown]
# **5 cities with lowest number of Female Graduates**

# %%
data_female_graduates_worst_city = pd.DataFrame(df['female_graduates'].groupby(df['name_of_city']).mean().sort_values()[:5])
data_female_graduates_worst_city['city_name'] = data_female_graduates_worst_city.index.values
frames = [data_female_graduates_worst_city,data_female_graduates_best_city]

# %% [markdown]
# **Concatenating the two dataframes and getting total 10 cities**

# %%
df2 = pd.concat(frames,ignore_index = True) 
df2
# Out:
#    female_graduates           city_name
# 0               829            Dabgram
# 1               988             Bagaha
# 2              1475            Jamuria
# 3              1493          Pithampur
# 4              1512         Mustafabad
# 5           1011097              Delhi
# 6            837407     Greater Mumbai
# 7            682800           Bengaluru
# 8            478747  Greater Hyderabad
# 9            392267            Chennai

# %%
data_sex.index.values
# Out:
# array(['HIMACHAL PRADESH', 'CHANDIGARH', 'NCT OF DELHI', 'HARYANA',
#        'PUNJAB'], dtype=object)

# %%
# to covert index into column
data_sex['state'] = data_sex.index.values

# %%
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
N = len(data_sex['sex_ratio'])
y = data_sex['sex_ratio']
x = range(N)
plt.bar(x,y,width = 0.5,color = "darkblue")
ax.set_xticklabels(data_sex['state'])
ax.set_xlabel('states')
ax.set_title('States having lowest Sex-Ratio')
# Out:
# Text(0.5, 1.0, 'States having lowest Sex-Ratio')

# %% [markdown]
# **Aggregated Sum of Population for all the states**

# %%
##population by states
x = df.groupby('state_name').agg({'population_total':np.sum})
x
# Out:
#                            population_total
# state_name
# ANDAMAN & NICOBAR ISLANDS            100608
# ANDHRA PRADESH                     18171615
# ASSAM                               1391154
# BIHAR                               6714516
# CHANDIGARH                           960787
# CHHATTISGARH                        3137918
# GUJARAT                            17835049
# HARYANA                             5952223
# HIMACHAL PRADESH                     169758
# JAMMU & KASHMIR                     1804987
# JHARKHAND                           4278259
# KARNATAKA                          15799896
# KERALA                              2755973
# MADHYA PRADESH                     11023091
# MAHARASHTRA                        37722136
# MANIPUR                              264986
# MEGHALAYA                            143007
# MIZORAM                              291822
# NAGALAND                             123777
# NCT OF DELHI                       13481997
# ORISSA                              3003234
# PUDUCHERRY                           541801
# PUNJAB                              5821876
# RAJASTHAN                          10443016
# TAMIL NADU                         13879395
# TRIPURA                              399688
# UTTAR PRADESH                      25302925
# UTTARAKHAND                         1340397
# WEST BENGAL                        18063509

# %%
x.sort_values('population_total',ascending = False)
##maharashtra has highest total population in given dataset
# Out:
#                            population_total
# state_name
# MAHARASHTRA                        37722136
# UTTAR PRADESH                      25302925
# ANDHRA PRADESH                     18171615
# WEST BENGAL                        18063509
# GUJARAT                            17835049
# KARNATAKA                          15799896
# TAMIL NADU                         13879395
# NCT OF DELHI                       13481997
# MADHYA PRADESH                     11023091
# RAJASTHAN                          10443016
# BIHAR                               6714516
# HARYANA                             5952223
# PUNJAB                              5821876
# JHARKHAND                           4278259
# CHHATTISGARH                        3137918
# ORISSA                              3003234
# KERALA                              2755973
# JAMMU & KASHMIR                     1804987
# ASSAM                               1391154
# UTTARAKHAND                         1340397
# CHANDIGARH                           960787
# PUDUCHERRY                           541801
# TRIPURA                              399688
# MIZORAM                              291822
# MANIPUR                              264986
# HIMACHAL PRADESH                     169758
# MEGHALAYA                            143007
# NAGALAND                             123777
# ANDAMAN & NICOBAR ISLANDS            100608

# %%
df['ratio_0-6_pop_total_pop'] = df['0-6_population_total']/df['population_total']

# %% [markdown]
# **Creating Pivot Table of ratio of 0-6 total population of all the states**

# %%
df.pivot_table(index = "state_name",values = "ratio_0-6_pop_total_pop")
# Out:
#                            ratio_0-6_pop_total_pop
# state_name
# ANDAMAN & NICOBAR ISLANDS                 0.093014
# ANDHRA PRADESH                            0.093932
# ASSAM                                     0.090769
# BIHAR                                     0.137608
# CHANDIGARH                                0.108444
# CHHATTISGARH                              0.114811
# GUJARAT                                   0.103970
# HARYANA                                   0.111613
# HIMACHAL PRADESH                          0.080385
# JAMMU & KASHMIR                           0.125107
# JHARKHAND                                 0.121954
# KARNATAKA                                 0.105243
# KERALA                                    0.087468
# MADHYA PRADESH                            0.117986
# MAHARASHTRA                               0.110352
# MANIPUR                                   0.097654
# MEGHALAYA                                 0.096443
# MIZORAM                                   0.120440
# NAGALAND                                  0.116645
# NCT OF DELHI                              0.128474
# ORISSA                                    0.094032
# PUDUCHERRY                                0.095035
# PUNJAB                                    0.103038
# RAJASTHAN                                 0.127813
# TAMIL NADU                                0.092705
# TRIPURA                                   0.084153
# UTTAR PRADESH                             0.117726
# UTTARAKHAND                               0.116781
# WEST BENGAL                               0.081955

# %% [markdown]
# **Distribution of Data of Total Effective Literacy Rate**

# %%
##plot of effective_literacy_rate_total
sns.distplot(df['effective_literacy_rate_total'])
fig = plt.figure()
res = stats.probplot(df['effective_literacy_rate_total'], plot=plt)

# %%
###heatmap of correlation matrix###
corr = df.corr()
fig,ax = plt.subplots(figsize = (12,9))
sns.heatmap(corr,vmax = 1.9)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Creating two new columns-Longitude and Latitude from a location variable**

# %%
##to split columns in a dataframe:
df1 = df.join(df['location'].str.split(',',expand=True).rename(columns = {0:'Latitude',1:'longitude'}))

# %%
df1['longitude']
# Out:
# 0      74.1993043
# 1      77.5086754
# 2       79.560344
# 3      86.1576889
# 4      77.2728368
#           ...
# 488    83.3955506
# 489    79.5940544
# 490    78.6021946
# 491    77.2673901
# 492    78.1204073
# Name: longitude, Length: 493, dtype: object

# %%
df['ratio_literate_total_pop'] = df['literates_total']/df['population_total']

# %%
chart1 = df[['name_of_city','state_name','ratio_literate_total_pop']]

# %%
chart1.sort_values('ratio_literate_total_pop').head(10)
#Top 10 cities with least ratio of literates - 70% in U.P.
# Out:
#     name_of_city      state_name  ratio_literate_total_pop
# 416     Sambhal    UTTAR PRADESH                  0.418408
# 39       Bagaha            BIHAR                  0.504354
# 396      Rampur    UTTAR PRADESH                  0.536538
# 27       Amroha    UTTAR PRADESH                  0.551764
# 6          Agra    UTTAR PRADESH                  0.559229
# 267      Khurja    UTTAR PRADESH                  0.581903
# 469        Tonk        RAJASTHAN                  0.597588
# 167   Firozabad    UTTAR PRADESH                  0.605083
# 4         Adoni   ANDHRA PRADESH                  0.608225
# 15      Aligarh    UTTAR PRADESH                  0.611946

# %%
chart1.sort_values('ratio_literate_total_pop').tail(10)
#Top 10 cities with highest ratio of literacy rates - west bengal and Kerala  have 40% of cities in bottom#
# Out:
#           name_of_city        state_name  ratio_literate_total_pop
# 431            Shimla   HIMACHAL PRADESH                  0.870645
# 333         Nagercoil         TAMIL NADU                  0.872593
# 278         Kozhikode             KERALA                  0.874880
# 14          Alappuzha             KERALA                  0.880027
# 155           Dum Dum        WEST BENGAL                  0.882010
# 352  North Barrackpur        WEST BENGAL                  0.889701
# 271             Kochi             KERALA                  0.889862
# 135         Darjiling        WEST BENGAL                  0.890611
# 461          Thrissur             KERALA                  0.894618
# 264          Khardaha        WEST BENGAL                  0.898479

# %%
df['state_name'].unique()
# States mentioned in dataset
# Out:
# array(['PUNJAB', 'MAHARASHTRA', 'ANDHRA PRADESH', 'JHARKHAND', 'TRIPURA',
#        'UTTAR PRADESH', 'GUJARAT', 'MIZORAM', 'RAJASTHAN', 'TAMIL NADU',
#        'KERALA', 'HARYANA', 'CHHATTISGARH', 'JAMMU & KASHMIR', 'BIHAR',
#        'WEST BENGAL', 'KARNATAKA', 'ORISSA', 'MADHYA PRADESH',
#        'NCT OF DELHI', 'CHANDIGARH', 'UTTARAKHAND', 'ASSAM', 'NAGALAND',
#        'MANIPUR ', 'PUDUCHERRY', 'ANDAMAN & NICOBAR ISLANDS', 'MEGHALAYA',
#        'HIMACHAL PRADESH'], dtype=object)

# %%
# to get a particular column
df[df['state_name'].map(lambda state_name: 'KERALA' in state_name)]
# Out:
#             name_of_city  state_code state_name  dist_code  population_total  \
# 14            Alappuzha           32     KERALA         11            174164
# 271               Kochi           32     KERALA          8            601574
# 275              Kollam           32     KERALA         13            349033
# 278           Kozhikode           32     KERALA          4            432097
# 358            Palakkad           32     KERALA          6            131019
# 459  Thiruvananthapuram           32     KERALA         14            752490
# 461            Thrissur           32     KERALA          7            315596
#
#      population_male  population_female  0-6_population_total  \
# 14             83888              90276                 15434
# 271           296668             304906                 52466
# 275           168076             180957                 31304
# 278           206494             225603                 41574
# 358            63833              67186                 11614
# 459           364657             387833                 61619
# 461           151999             163597                 25252
#
#      0-6_population_male  0-6_population_female  ...  \
# 14                  7934                   7500  ...
# 271                26863                  25603  ...
# 275                16018                  15286  ...
# 278                21208                  20366  ...
# 358                 5930                   5684  ...
# 459                31156                  30463  ...
# 461                12953                  12299  ...
#
#      effective_literacy_rate_total  effective_literacy_rate_male  \
# 14                           96.56                         98.03
# 271                          97.49                         98.31
# 275                          92.10                         93.85
# 278                          96.80                         97.93
# 358                          94.20                         96.83
# 459                          93.72                         94.94
# 461                          97.24                         98.31
#
#      effective_literacy_rate_female               location  total_graduates  \
# 14                            95.21   9.4980667,76.3388484            22263
# 271                           96.69   9.9312328,76.2673041           115773
# 275                           90.50   8.8932118,76.6141396            39521
# 278                           95.78    11.2587531,75.78041            61225
# 358                           91.73  10.7867303,76.6547932            16827
# 459                           92.58   8.5241391,76.9366376           151257
# 461                           96.26  10.5276416,76.2144349            53535
#
#      male_graduates  female_graduates  ratio_0-6_pop_total_pop  \
# 14             9900             12363                 0.088618
# 271           54538             61235                 0.087215
# 275           17708             21813                 0.089688
# 278           27701             33524                 0.096215
# 358            8436              8391                 0.088644
# 459           72759             78498                 0.081887
# 461           24392             29143                 0.080014
#
#     ratio_literate_total_pop  ratio_male_female_eff_literacy_rate
# 14                  0.880027                             1.029619
# 271                 0.889862                             1.016755
# 275                 0.838434                             1.037017
# 278                 0.874880                             1.022447
# 358                 0.858494                             1.055598
# 459                 0.860449                             1.025491
# 461                 0.894618                             1.021296
#
# [7 rows x 25 columns]

# %%
value = ['KERALA','BIHAR']
df_B_K = pd.DataFrame(df[df.state_name.isin(value)])

# %% [markdown]
# **Created a DataFrame for Only 2 States**

# %%
#bar chart for litearcy rates for kerala and bihar
ax = plt.subplot()
ax.set_ylabel = 'effective_literacy_rate_total'
ax.set_title('Comparison of Bihar and Kerala')
df_B_K.groupby('state_name').mean()['effective_literacy_rate_total'].plot(kind='bar',figsize=(10,8), ax = ax,color = ('coral','aquamarine'))
# Out:
# <AxesSubplot:title={'center':'Comparison of Bihar and Kerala'}, xlabel='state_name'>

# %%
###top 2 and bottom 2 states with child sex ratio 
data_female_child_sex_worst_states = pd.DataFrame(df['child_sex_ratio'].groupby(df['state_name']).mean().sort_values()[:2])
data_female_child_sex_worst_states['state_name'] = data_female_child_sex_worst_states.index.values

# %%
###top 2 and bottom 2 states with child sex ratio 
data_female_child_sex_best_states = pd.DataFrame(df['child_sex_ratio'].groupby(df['state_name']).mean().sort_values(ascending =False)[:2])
data_female_child_sex_best_states['state_name'] = data_female_child_sex_best_states.index.values
frame1 = [data_female_child_sex_best_states,data_female_child_sex_worst_states]

# %%
###Mizoram and Assam have good child sex ratio and Haryana and punjab have lowest 
df3 = pd.concat(frame1 ,ignore_index=True)
df3
# Out:
#    child_sex_ratio state_name
# 0         989.0000    MIZORAM
# 1         982.7500      ASSAM
# 2         822.7000    HARYANA
# 3         851.3125     PUNJAB

# %%
df['ratio_male_female_eff_literacy_rate']=df['effective_literacy_rate_male']/df['effective_literacy_rate_female']

# %% [markdown]
# **Analysing the dataframes of the cities having more number of male literates as compared to female**

# %%
data_ratio_male_female_eff_literacy_rate_worst_cities = pd.DataFrame(df['ratio_male_female_eff_literacy_rate'].groupby(df['name_of_city']).mean().sort_values(ascending =False)[:10])
data_ratio_male_female_eff_literacy_rate_worst_cities
# Out:
#                  ratio_male_female_eff_literacy_rate
# name_of_city
# Hindaun                                     1.373006
# Churu                                       1.371175
# Bagaha                                      1.364442
# Sujangarh                                   1.357120
# Gangapur City                               1.344787
# Jhunjhunun                                  1.341348
# Tadpatri                                    1.332311
# Pali                                        1.331992
# Sawai Madhopur                              1.324754
# Tonk                                        1.314954

# %%
data_ratio_male_female_eff_literacy_rate_worst_states = pd.DataFrame(df['ratio_male_female_eff_literacy_rate'].groupby(df['state_name']).mean().sort_values(ascending =False)[:10])
data_ratio_male_female_eff_literacy_rate_worst_states
# Out:
#                  ratio_male_female_eff_literacy_rate
# state_name
# RAJASTHAN                                   1.246380
# NCT OF DELHI                                1.176095
# JAMMU & KASHMIR                             1.162788
# ANDHRA PRADESH                              1.159527
# BIHAR                                       1.156691
# MADHYA PRADESH                              1.155393
# JHARKHAND                                   1.150882
# CHHATTISGARH                                1.148998
# UTTAR PRADESH                               1.134702
# GUJARAT                                     1.131896

# %% [markdown]
# **Top 10 Cities with highest Total Graduates**

# %%
data_female_child_sex_best_cities = pd.DataFrame(df['total_graduates'].groupby(df['name_of_city']).mean().sort_values(ascending =False)[:10])
data_female_child_sex_best_cities
# Out:
#                     total_graduates
# name_of_city
# Delhi                     2221137.0
# Greater Mumbai            1802371.0
# Bengaluru                 1591163.0
# Greater Hyderabad         1164149.0
# Chennai                    879695.0
# Kolkata                    818476.0
# Ahmadabad                  769858.0
# Pune                       656508.0
# Lucknow                    596990.0
# Jaipur                     533148.0

# %% [markdown]
# **Delhi has the highest number of Graduates**

# %%
## Dataframe contains only Haryana state and I am analysing child sex ratio of different cities in Haryana
value = ['HARYANA']
df_H = pd.DataFrame(df[df.state_name.isin(value)])

# %%
df_H
# Out:
#       name_of_city  state_code state_name  dist_code  population_total  \
# 18         Ambala            6    HARYANA          2            196216
# 19   Ambala Sadar            6    HARYANA          2            104268
# 41    Bahadurgarh            6    HARYANA         15            170426
# 90        Bhiwani            6    HARYANA         13            197662
# 164     Faridabad            6    HARYANA         20           1404653
# 192       Gurgaon            6    HARYANA         18            876824
# 212         Hisar            6    HARYANA         12            301249
# 223      Jagadhri            6    HARYANA          3            124915
# 240          Jind            6    HARYANA          9            166225
# 244       Kaithal            6    HARYANA          5            144633
# 256        Karnal            6    HARYANA          6            286974
# 362        Palwal            6    HARYANA         21            127931
# 363     Panchkula            6    HARYANA          1            210175
# 365       Panipat            6    HARYANA          7            294150
# 404        Rewari            6    HARYANA         17            140864
# 407        Rohtak            6    HARYANA         14            373133
# 438         Sirsa            6    HARYANA         11            183282
# 442       Sonipat            6    HARYANA          8            277053
# 457      Thanesar            6    HARYANA          4            154962
# 491   Yamunanagar            6    HARYANA          3            216628
#
#      population_male  population_female  0-6_population_total  \
# 18            103533              92683                 19645
# 19             54241              50027                  9646
# 41             91736              78690                 20374
# 90            105372              92290                 22507
# 164           750446             654207                176773
# 192           475612             401212                108623
# 212           163338             137911                 33514
# 223            67752              57163                 13635
# 240            88561              77664                 18825
# 244            76657              67976                 16690
# 256           151668             135306                 31291
# 362            67887              60044                 15662
# 363           111622              98553                 22111
# 365           157302             136848                 35477
# 404            74689              66175                 15986
# 407           197754             175379                 40715
# 438            96806              86476                 20161
# 442           147933             129120                 30809
# 457            83655              71307                 15594
# 491           115404             101224                 22905
#
#      0-6_population_male  0-6_population_female  ...  \
# 18                 10713                   8932  ...
# 19                  5239                   4407  ...
# 41                 11420                   8954  ...
# 90                 12444                  10063  ...
# 164                95808                  80965  ...
# 192                58842                  49781  ...
# 212                18015                  15499  ...
# 223                 7484                   6151  ...
# 240                10280                   8545  ...
# 244                 9156                   7534  ...
# 256                17319                  13972  ...
# 362                 8614                   7048  ...
# 363                12024                  10087  ...
# 365                19246                  16231  ...
# 404                 8958                   7028  ...
# 407                22711                  18004  ...
# 438                11161                   9000  ...
# 442                17232                  13577  ...
# 457                 8401                   7193  ...
# 491                12556                  10349  ...
#
#      effective_literacy_rate_total  effective_literacy_rate_male  \
# 18                           88.23                         91.58
# 19                           87.97                         88.66
# 41                           88.04                         94.27
# 90                           84.39                         90.42
# 164                          84.88                         90.44
# 192                          86.30                         89.54
# 212                          81.04                         86.13
# 223                          85.79                         89.04
# 240                          83.63                         90.86
# 244                          80.76                         87.65
# 256                          86.32                         90.55
# 362                          81.00                         87.78
# 363                          87.86                         91.31
# 365                          84.29                         88.83
# 404                          88.25                         94.22
# 407                          84.08                         88.94
# 438                          83.03                         88.50
# 442                          87.56                         93.21
# 457                          85.73                         89.89
# 491                          85.91                         89.61
#
#      effective_literacy_rate_female               location  total_graduates  \
# 18                            84.51  30.3781788,76.7766974            34943
# 19                            87.22  30.3248708,76.8432663            20618
# 41                            80.87  28.6924464,76.9239727            22521
# 90                            77.56  28.7751693,75.9927652            28123
# 164                           78.53  28.4089123,77.3177894           219974
# 192                           82.46  28.4594965,77.0266383           233817
# 212                           75.00  29.1491875,75.7216527            49148
# 223                           81.96  30.1680858,77.2969204            18738
# 240                           75.43  29.3211153,76.3058328            21508
# 244                           73.07  29.7856734,76.3984537            18095
# 256                           81.64  29.6856929,76.9904825            52911
# 362                           73.42  28.1487362,77.3320262            15837
# 363                           83.98   30.6942091,76.860565            62655
# 365                           79.09  29.3909464,76.9635023            37873
# 404                           81.61  28.1927631,76.6239423            22539
# 407                           78.68   28.8955152,76.606611            65881
# 438                           76.98  29.5335931,75.0177029            24453
# 442                           81.17   28.9287735,77.091281            46858
# 457                           80.85  29.9696148,76.8197522            32979
# 491                           81.71  30.1290485,77.2673901            29803
#
#      male_graduates  female_graduates  ratio_0-6_pop_total_pop  \
# 18            17809             17134                 0.100119
# 19            10689              9929                 0.092512
# 41            13025              9496                 0.119547
# 90            17068             11055                 0.113866
# 164          123138             96836                 0.125848
# 192          126456            107361                 0.123882
# 212           27629             21519                 0.111250
# 223            9805              8933                 0.109154
# 240           12601              8907                 0.113250
# 244           10125              7970                 0.115396
# 256           27708             25203                 0.109038
# 362            9276              6561                 0.122425
# 363           32821             29834                 0.105203
# 365           19231             18642                 0.120609
# 404           12960              9579                 0.113485
# 407           35890             29991                 0.109117
# 438           13473             10980                 0.110000
# 442           25676             21182                 0.111203
# 457           18192             14787                 0.100631
# 491           14349             15454                 0.105734
#
#     ratio_literate_total_pop  ratio_male_female_eff_literacy_rate
# 18                  0.793921                             1.083659
# 19                  0.798289                             1.016510
# 41                  0.775163                             1.165698
# 90                  0.747777                             1.165807
# 164                 0.741940                             1.151662
# 192                 0.756103                             1.085860
# 212                 0.720261                             1.148400
# 223                 0.764272                             1.086384
# 240                 0.741567                             1.204561
# 244                 0.714422                             1.199535
# 256                 0.769098                             1.109138
# 362                 0.710828                             1.195587
# 363                 0.786178                             1.087283
# 365                 0.741197                             1.123151
# 404                 0.782350                             1.154515
# 407                 0.749087                             1.130402
# 438                 0.738943                             1.149649
# 442                 0.778223                             1.148331
# 457                 0.771041                             1.111812
# 491                 0.768225                             1.096683
#
# [20 rows x 25 columns]

# %% [markdown]
# **Scatterplot:Total Population and Sex-Ratio**

# %%
sns.jointplot(np.sqrt(df['sex_ratio']),np.sqrt(df['population_total']),color='crimson')

# %% [markdown]
# **Scatterplot:Total Graduates and Female Graduates**

# %%
with sns.axes_style("white"):
    sns.jointplot(df['female_graduates'],df['total_graduates'],color='darkgreen')
